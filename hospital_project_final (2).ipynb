# %%
# !pip install sqlalchemy pandas pymysql
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\ramam\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: pandas in c:\users\ramam\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: pymysql in c:\users\ramam\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ramam\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ramam\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ramam\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramam\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramam\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramam\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ramam\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sqlalchemy in c:\users\ramam\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ramam\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ramam\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

engine = create_engine("mysql+pymysql://root:Rama%40123@localhost/hospital_project")

# %%
import os
os.listdir("C:/Users/ramam/Downloads/health_operation task/")
# Out:
# ['admissions_raw.csv',
#  'billing_claims_raw.csv',
#  'departments.csv',
#  'doctors (1).csv',
#  'doctors.csv',
#  'followups_raw.csv',
#  'Hospital Project DB.png',
#  'hospitals.csv',
#  'Images in DB.png',
#  'lab_results_raw.csv',
#  'patients_raw.csv',
#  'pharmacy_orders_raw.csv',
#  'Power BI Introduction (1).odt',
#  'treatments_raw.csv']

# %%
from sqlalchemy import create_engine
import pandas as pd
import os
import mysql.connector

# MySQL URI format
# URL-encoded password
# Original password: Rp@2121994 → Encoded: Rp%402121994
engine = create_engine("mysql+pymysql://root:Rama%40123@localhost/hospital_project")

#  Path to the dataset files

DATA_PATH = "C:/Users/ramam/Downloads/health_operation task/"


#  MySQL connector config
config = {
    'user': 'root',
    'password': 'Rama@123',   # Raw password is fine here
    'host': 'localhost',
    'database': 'hospital_project',
    'raise_on_warnings': True
}

#  Connect and insert
try:
    conn = mysql.connector.connect(**config)
    cursor = conn.cursor()
    print(" MySQL connection established successfully.")

    csv_files = [
        'admissions_raw.csv', 
        'billing_claims_raw.csv', 
        'departments.csv', 'doctors.csv', 
        'followups_raw.csv', 
        'hospitals.csv', 
        'lab_results_raw.csv', 
        'patients_raw.csv', 
        'pharmacy_orders_raw.csv', 
        'treatments_raw.csv'
    ]

    for file in csv_files:
        df = pd.read_csv(os.path.join(DATA_PATH, file))
        table_name = file.replace('.csv', '').replace('_raw', '')
        df.to_sql(name=table_name, con=engine, if_exists='replace', index=False)
        print(f" Table '{table_name}' created successfully.")

except mysql.connector.Error as err:
    print(f" Error: {err}")
finally:
    if conn.is_connected():
        cursor.close()
        conn.close()
        print(" MySQL connection closed.")
# Out:
#  MySQL connection established successfully.
#  Table 'admissions' created successfully.
#  Table 'billing_claims' created successfully.
#  Table 'departments' created successfully.
#  Table 'doctors' created successfully.
#  Table 'followups' created successfully.
#  Table 'hospitals' created successfully.
#  Table 'lab_results' created successfully.
#  Table 'patients' created successfully.
#  Table 'pharmacy_orders' created successfully.
#  Table 'treatments' created successfully.
#  MySQL connection closed.

# %%
patients = pd.read_sql('SELECT * FROM patients;', engine)
admissions = pd.read_sql('SELECT * FROM admissions;', engine)
treatments = pd.read_sql('SELECT * FROM treatments;', engine)
billing = pd.read_sql('SELECT * FROM billing_claims;', engine)
pharmacy = pd.read_sql('SELECT * FROM pharmacy_orders;', engine)
labs = pd.read_sql('SELECT * FROM lab_results;', engine)
followups = pd.read_sql('SELECT * FROM followups;', engine)
doctors = pd.read_sql('SELECT * FROM doctors;', engine)
departments = pd.read_sql('SELECT * FROM departments;', engine)
hospitals = pd.read_sql('SELECT * FROM hospitals;', engine)





print('patients:', patients.shape)
print('admissions:', admissions.shape)
print('treatments:', treatments.shape)
print('billing:', billing.shape)
print('pharmacy:', pharmacy.shape)
print('labs:', labs.shape)
print('followups:', followups.shape)
print('doctors',doctors.shape)
print('departments:', departments.shape)
print('hospitals:',hospitals.shape)
# Out:
# patients: (12090, 10)
# admissions: (30130, 12)
# treatments: (90160, 7)
# billing: (30080, 10)
# pharmacy: (70090, 8)
# labs: (60000, 7)
# followups: (30000, 7)
# doctors (260, 7)
# departments: (12, 3)
# hospitals: (8, 6)

# %%
print(patients.columns)
print(admissions.columns)
print(treatments.columns)
print(billing.columns)
print(pharmacy.columns)
print(labs.columns)
print(followups.columns)
print(doctors.columns)
print(departments.columns)
print(hospitals.columns)
# Out:
# Index(['patient_id', 'patient_code', 'patient_name', 'age', 'gender', 'city',
#        'primary_chronic_condition', 'insurance_plan', 'income_segment',
#        'registration_date'],
#       dtype='object')
# Index(['admission_id', 'patient_id', 'hospital_id', 'department_id',
#        'primary_doctor_id', 'admission_date', 'discharge_date',
#        'admission_type', 'diagnosis', 'severity_level', 'discharge_status',
#        'readmitted_30_days'],
#       dtype='object')
# Index(['treatment_id', 'admission_id', 'doctor_id', 'treatment_type',
#        'treatment_cost', 'treatment_date', 'treatment_status'],
#       dtype='object')
# Index(['bill_id', 'admission_id', 'patient_id', 'payer_type', 'gross_amount',
#        'discount_amount', 'insurance_paid', 'patient_paid', 'claim_status',
#        'bill_date'],
#       dtype='object')
# Index(['order_id', 'admission_id', 'patient_id', 'medicine_name', 'quantity',
#        'unit_price', 'line_amount', 'pharmacy_type'],
#       dtype='object')
# Index(['lab_id', 'admission_id', 'patient_id', 'test_name', 'test_value',
#        'test_date', 'result_flag'],
#       dtype='object')
# Index(['followup_id', 'admission_id', 'patient_id', 'followup_due_date',
#        'followup_completed', 'followup_mode', 'followup_outcome'],
#       dtype='object')
# Index(['doctor_id', 'doctor_name', 'department_id', 'specialization',
#        'hospital_id', 'experience_years', 'doctor_grade'],
#       dtype='object')
# Index(['department_id', 'department_name', 'care_complexity'], dtype='object')
# Index(['hospital_id', 'hospital_name', 'city', 'ownership_type',
#        'bed_capacity', 'launch_year'],
#       dtype='object')

# %%
patients.head()
# Out:
#    patient_id patient_code   patient_name   age  gender       city  \
# 0           1       P00001  Patient_BKOKF  46.0  Female  Hyderabad
# 1           2       P00002  Patient_KXPSW  58.0    Male  Hyderabad
# 2           3       P00003  Patient_TJAJT  51.0  Female  Ahmedabad
# 3           4       P00004  Patient_WYKTO  25.0    Male       None
# 4           5       P00005  Patient_PFFLA  54.0    Male       None
#
#   primary_chronic_condition     insurance_plan income_segment  \
# 0             Heart Failure  Premium Insurance            Low
# 1             Heart Failure    Basic Insurance            Low
# 2              Hypertension  Government Scheme         Middle
# 3             Heart Failure           Self Pay         Middle
# 4                    Asthma    Basic Insurance         Middle
#
#   registration_date
# 0        2016-09-25
# 1        2022-09-12
# 2        2014-08-02
# 3        2017-03-23
# 4        2021-11-22

# %%
admissions.head()
# Out:
#    admission_id  patient_id  hospital_id  department_id  primary_doctor_id  \
# 0             1        3415            8              4                123
# 1             2        3610            8              1                209
# 2             3        7584            8              3                190
# 3             4        4459            2              3                176
# 4             5        5508            3             12                140
#
#   admission_date discharge_date admission_type                diagnosis  \
# 0     2024-03-10     2024-03-16      Emergency                   Anemia
# 1     2023-05-19     2023-05-20        Planned               Arrhythmia
# 2     2025-06-16     2025-06-18      Emergency        Joint Replacement
# 3     2025-10-15     2025-10-16       Referral        Joint Replacement
# 4     2024-05-07     2024-05-23        Planned  Multi Organ Dysfunction
#
#   severity_level discharge_status readmitted_30_days
# 0       Critical             Home                Yes
# 1       Moderate             Home                 No
# 2       Moderate             Home                Yes
# 3       Moderate             Home                 No
# 4       Moderate             Home                 No

# %%
treatments.head()
# Out:
#    treatment_id  admission_id  doctor_id treatment_type  treatment_cost  \
# 0             1         27337         62        Surgery        52636.30
# 1             2           982        242        Imaging         7478.12
# 2             3         17082        238   Chemotherapy        27451.58
# 3             4          4096          1    Lab Package         3379.43
# 4             5         26108        227       ICU Care        19993.51
#
#   treatment_date treatment_status
# 0     2023-01-01        Completed
# 1     2023-01-01        Completed
# 2     2023-01-01        Completed
# 3     2023-01-01          Pending
# 4     2023-01-01        Completed

# %%
billing.head()
# Out:
#    bill_id  admission_id  patient_id           payer_type  gross_amount  \
# 0        1             1        3415    Premium Insurance      19940.46
# 1        2             2        3610      Basic Insurance      19034.64
# 2        3             3        7584             Self Pay      20965.03
# 3        4             4        4459  Corporate Insurance      16637.20
# 4        5             5        5508    Government Scheme      77727.52
#
#    discount_amount  insurance_paid  patient_paid claim_status   bill_date
# 0          1785.84        15939.06       2215.56         Paid  2024-03-10
# 1           558.14        13981.49       4495.01      Partial  2023-05-19
# 2          2413.86        18595.28          0.00     Rejected  2025-06-16
# 3          1938.84        13657.64       1040.72     Rejected  2025-10-15
# 4          2213.24        35959.21      39555.07         Paid  2024-05-07

# %%
pharmacy.head()
# Out:
#    order_id  admission_id  patient_id      medicine_name  quantity  \
# 0         1         29377        7899            Insulin        15
# 1         2         25956        2404      Anticoagulant         1
# 2         3         18883        6450  Chemotherapy Drug        17
# 3         4         21967       10792          Metformin         3
# 4         5         17705        4645         Amlodipine        20
#
#    unit_price  line_amount pharmacy_type
# 0       57.66       864.90   IP Pharmacy
# 1       33.52        33.52   IP Pharmacy
# 2      188.65      3207.07   OP Pharmacy
# 3       37.73       113.18   OP Pharmacy
# 4       95.68      1913.64   OP Pharmacy

# %%
labs.head()
# Out:
#    lab_id  admission_id  patient_id   test_name  test_value   test_date  \
# 0       1          2133       11981         CRP        5.99  2023-01-01
# 1       2          5569        5064      Sodium        2.46  2023-01-01
# 2       3         17271        1824         CRP        2.84  2023-01-01
# 3       4         24486        9939       HbA1c       14.91  2023-01-01
# 4       5         21094        8920  Hemoglobin       11.46  2023-01-01
#
#   result_flag
# 0    Abnormal
# 1      Normal
# 2    Abnormal
# 3      Normal
# 4    Abnormal

# %%
doctors.head()
# Out:
#    doctor_id      doctor_name  department_id    specialization  hospital_id  \
# 0          1   Dr. Sai Sharma              4  General Medicine            8
# 1          2     Dr. Raj Nair             12               ICU            7
# 2          3  Dr. Ishaan Khan              9         Emergency            6
# 3          4      Dr. Sai Rao              7  Gastroenterology            7
# 4          5  Dr. Priya Menon              2         Neurology            2
#
#    experience_years       doctor_grade
# 0                 9         Consultant
# 1                10           Resident
# 2                16         Consultant
# 3                 7         Consultant
# 4                12  Senior Consultant

# %%
followups.head()
# Out:
#    followup_id  admission_id  patient_id followup_due_date followup_completed  \
# 0            1             1        3415        2024-03-30                Yes
# 1            2             2        3610        2023-05-27                Yes
# 2            3             3        7584        2025-07-02                Yes
# 3            4             4        4459        2025-10-23                 No
# 4            5             5        5508        2024-05-30                Yes
#
#   followup_mode followup_outcome
# 0     OPD Visit           Stable
# 1     OPD Visit           Stable
# 2  Telemedicine           Stable
# 3          Call    Referred Back
# 4          Call           Stable

# %%
departments.head()
# Out:
#    department_id   department_name care_complexity
# 0              1        Cardiology            High
# 1              2         Neurology            High
# 2              3       Orthopedics          Medium
# 3              4  General Medicine          Medium
# 4              5       Pulmonology            High

# %%
doctors.head()
# Out:
#    doctor_id      doctor_name  department_id    specialization  hospital_id  \
# 0          1   Dr. Sai Sharma              4  General Medicine            8
# 1          2     Dr. Raj Nair             12               ICU            7
# 2          3  Dr. Ishaan Khan              9         Emergency            6
# 3          4      Dr. Sai Rao              7  Gastroenterology            7
# 4          5  Dr. Priya Menon              2         Neurology            2
#
#    experience_years       doctor_grade
# 0                 9         Consultant
# 1                10           Resident
# 2                16         Consultant
# 3                 7         Consultant
# 4                12  Senior Consultant

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12090 entries, 0 to 12089
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   patient_id                 12090 non-null  int64
#  1   patient_code               12090 non-null  object
#  2   patient_name               12090 non-null  object
#  3   age                        11879 non-null  float64
#  4   gender                     12090 non-null  object
#  5   city                       11920 non-null  object
#  6   primary_chronic_condition  8841 non-null   object
#  7   insurance_plan             12090 non-null  object
#  8   income_segment             12090 non-null  object
#  9   registration_date          12090 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 944.7+ KB

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30130 entries, 0 to 30129
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   admission_id        30130 non-null  int64
#  1   patient_id          30130 non-null  int64
#  2   hospital_id         30130 non-null  int64
#  3   department_id       30130 non-null  int64
#  4   primary_doctor_id   30130 non-null  int64
#  5   admission_date      30130 non-null  object
#  6   discharge_date      29879 non-null  object
#  7   admission_type      30130 non-null  object
#  8   diagnosis           29987 non-null  object
#  9   severity_level      30130 non-null  object
#  10  discharge_status    30130 non-null  object
#  11  readmitted_30_days  30130 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.8+ MB

# %%
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90160 entries, 0 to 90159
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   treatment_id      90160 non-null  int64
#  1   admission_id      90160 non-null  int64
#  2   doctor_id         90160 non-null  int64
#  3   treatment_type    90160 non-null  object
#  4   treatment_cost    89860 non-null  float64
#  5   treatment_date    90160 non-null  object
#  6   treatment_status  90160 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 4.8+ MB

# %%
billing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30080 entries, 0 to 30079
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   bill_id          30080 non-null  int64
#  1   admission_id     30080 non-null  int64
#  2   patient_id       30080 non-null  int64
#  3   payer_type       30080 non-null  object
#  4   gross_amount     29960 non-null  float64
#  5   discount_amount  30080 non-null  float64
#  6   insurance_paid   30080 non-null  float64
#  7   patient_paid     30080 non-null  float64
#  8   claim_status     30080 non-null  object
#  9   bill_date        30080 non-null  object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 2.3+ MB

# %%
pharmacy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70090 entries, 0 to 70089
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       70090 non-null  int64
#  1   admission_id   70090 non-null  int64
#  2   patient_id     70090 non-null  int64
#  3   medicine_name  70090 non-null  object
#  4   quantity       70090 non-null  int64
#  5   unit_price     70090 non-null  float64
#  6   line_amount    69940 non-null  float64
#  7   pharmacy_type  70090 non-null  object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 4.3+ MB

# %%
labs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lab_id        60000 non-null  int64
#  1   admission_id  60000 non-null  int64
#  2   patient_id    60000 non-null  int64
#  3   test_name     60000 non-null  object
#  4   test_value    59880 non-null  float64
#  5   test_date     60000 non-null  object
#  6   result_flag   60000 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.2+ MB

# %%
doctors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   doctor_id         260 non-null    int64
#  1   doctor_name       260 non-null    object
#  2   department_id     260 non-null    int64
#  3   specialization    260 non-null    object
#  4   hospital_id       260 non-null    int64
#  5   experience_years  260 non-null    int64
#  6   doctor_grade      260 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 14.3+ KB

# %%
followups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   followup_id         30000 non-null  int64
#  1   admission_id        30000 non-null  int64
#  2   patient_id          30000 non-null  int64
#  3   followup_due_date   30000 non-null  object
#  4   followup_completed  30000 non-null  object
#  5   followup_mode       30000 non-null  object
#  6   followup_outcome    30000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.6+ MB

# %%
departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   department_id    12 non-null     int64
#  1   department_name  12 non-null     object
#  2   care_complexity  12 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 420.0+ bytes

# %%
hospitals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hospital_id     8 non-null      int64
#  1   hospital_name   8 non-null      object
#  2   city            8 non-null      object
#  3   ownership_type  8 non-null      object
#  4   bed_capacity    8 non-null      int64
#  5   launch_year     8 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 516.0+ bytes

# %%
def create_quality_report(df, table_name):
    report = pd.DataFrame()
    report['table_name'] = [table_name] * len(df.columns)
    report['column_name'] = df.columns      
    report['data_type'] = df.dtypes.astype(str).values
    report['missing_count'] = df.isna().sum().values
    report['missing_percentage'] = (df.isna().mean() * 100).round(2).values
    report['unique_values'] = df.nunique(dropna=True).values
    return report

patients_quality = create_quality_report(patients, 'patients')
admissions_quality = create_quality_report(admissions, 'admissions')
treatments_quality = create_quality_report(treatments, 'treatments')
billing_quality = create_quality_report(billing, 'billing')
pharmacy_quality = create_quality_report(pharmacy,'pharmacy')
labs_quality = create_quality_report(labs,'labs')
doctors_quality = create_quality_report(doctors,'doctors')
followups_quality = create_quality_report(followups,'followups')
departments_quality = create_quality_report(departments,'departments')
hospitals_quality = create_quality_report(hospitals,'hospitals')

quality_report = pd.concat(
    [patients_quality, admissions_quality, treatments_quality,billing_quality,pharmacy_quality,labs_quality,doctors_quality,followups_quality,
departments_quality,hospitals_quality],
    ignore_index=True
)

quality_report.sort_values('missing_percentage', ascending=False).head(n=100)
# Out:
#     table_name                column_name data_type  missing_count  \
# 6     patients  primary_chronic_condition    object           3249
# 3     patients                        age   float64            211
# 5     patients                       city    object            170
# 16  admissions             discharge_date    object            251
# 18  admissions                  diagnosis    object            143
# ..         ...                        ...       ...            ...
# 72   hospitals              hospital_name    object              0
# 73   hospitals                       city    object              0
# 74   hospitals             ownership_type    object              0
# 75   hospitals               bed_capacity     int64              0
# 76   hospitals                launch_year     int64              0
#
#     missing_percentage  unique_values
# 6                26.87              7
# 3                 1.75            101
# 5                 1.41             14
# 16                0.83           1099
# 18                0.47             43
# ..                 ...            ...
# 72                0.00              8
# 73                0.00              8
# 74                0.00              2
# 75                0.00              8
# 76                0.00              8
#
# [77 rows x 6 columns]

# %% [markdown]
# ### 6. Clean Patient Master Data

# %%
patients_clean = patients.copy()
print('Before duplicate removal:', patients_clean.shape)
patients_clean = patients_clean.drop_duplicates()
print('After duplicate removal:', patients_clean.shape)
# Out:
# Before duplicate removal: (12090, 10)
# After duplicate removal: (12090, 10)

# %%
# Convert age to numeric.
# If age contains text or invalid values, errors='coerce' converts them to NaN.
patients_clean['age_clean'] = pd.to_numeric(patients_clean['age'], errors='coerce')

# Mark impossible ages as missing.
patients_clean.loc[patients_clean['age_clean'] < 0, 'age_clean'] = np.nan
patients_clean.loc[patients_clean['age_clean'] > 110, 'age_clean'] = np.nan

# Fill missing age using median because median is less affected by outliers.
median_age = patients_clean['age_clean'].median()
patients_clean['age_clean'] = patients_clean['age_clean'].fillna(median_age)

patients_clean[['age', 'age_clean']].head()
# Out:
#     age  age_clean
# 0  46.0       46.0
# 1  58.0       58.0
# 2  51.0       51.0
# 3  25.0       25.0
# 4  54.0       54.0

# %%
# Standardize gender values.
patients_clean['gender_clean'] = patients_clean['gender'].astype(str).str.strip().str.lower()

patients_clean['gender_clean'] = patients_clean['gender_clean'].replace({
    'm': 'Male',
    'male': 'Male',
    'f': 'Female',
    'female': 'Female',
    'femle': 'Female',
    'other': 'Other',
    'unknown': 'Unknown',
    'nan': 'Unknown'
})

patients_clean['gender_clean'].value_counts()
# Out:
# gender_clean
# Female     6125
# Male       5769
# Other       130
# Unknown      66
# Name: count, dtype: int64

# %%
patients_clean['primary_chronic_condition'].value_counts()
# Out:
# primary_chronic_condition
# Hypertension     2387
# Diabetes         2134
# Asthma           1058
# COPD              975
# Heart Failure     937
# CKD               876
# Cancer            474
# Name: count, dtype: int64

# %%
# Standardize chronic condition values.
patients_clean['chronic_condition_clean'] = (
    patients_clean['primary_chronic_condition']
    .astype(str)
    .str.strip()
    .str.title()
)

# %%
patients_clean['chronic_condition_clean'].value_counts()
# Out:
# chronic_condition_clean
# None             3249
# Hypertension     2387
# Diabetes         2134
# Asthma           1058
# Copd              975
# Heart Failure     937
# Ckd               876
# Cancer            474
# Name: count, dtype: int64

# %%
# Replace missing/blank/unwanted text with Unknown
patients_clean['chronic_condition_clean'] = patients_clean['chronic_condition_clean'].replace({
    'Nan': 'Unknown',
    '': 'Unknown',
    'None': 'Unknown',
    'Null': 'Unknown'
})

# %%
patients_clean['chronic_condition_clean'].value_counts()
# Out:
# chronic_condition_clean
# Unknown          3249
# Hypertension     2387
# Diabetes         2134
# Asthma           1058
# Copd              975
# Heart Failure     937
# Ckd               876
# Cancer            474
# Name: count, dtype: int64

# %%
# Create chronic flag
# If chronic condition is available, flag = 1
# If missing/unknown, flag = 0
patients_clean['chronic_flag'] = patients_clean['chronic_condition_clean'].apply(
    lambda x: 0 if x == 'Unknown' else 1
)

patients_clean[['primary_chronic_condition', 'chronic_condition_clean', 'chronic_flag']].head()
# Out:
#   primary_chronic_condition chronic_condition_clean  chronic_flag
# 0             Heart Failure           Heart Failure             1
# 1             Heart Failure           Heart Failure             1
# 2              Hypertension            Hypertension             1
# 3             Heart Failure           Heart Failure             1
# 4                    Asthma                  Asthma             1

# %%
patients_clean['chronic_flag'].value_counts()
# Out:
# chronic_flag
# 1    8841
# 0    3249
# Name: count, dtype: int64

# %%
patients_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\patients_clean.csv")

# %% [markdown]
# ### 7. Clean Admissions Data

# %%
admissions_clean = admissions.copy()
print('Before duplicate removal:',admissions_clean.shape)
admissions_clean = admissions_clean.drop_duplicates()
print('After duplicate removal:', admissions_clean.shape)
# Out:
# Before duplicate removal: (30130, 12)
# After duplicate removal: (30000, 12)

# %%
patients_clean = patients.copy()
print('Before duplicate removal:', patients_clean.shape)
patients_clean = patients_clean.drop_duplicates()
print('After duplicate removal:', patients_clean.shape)
# Out:
# Before duplicate removal: (12090, 10)
# After duplicate removal: (12090, 10)

# %%
admissions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30000 entries, 0 to 29999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   admission_id        30000 non-null  int64
#  1   patient_id          30000 non-null  int64
#  2   hospital_id         30000 non-null  int64
#  3   department_id       30000 non-null  int64
#  4   primary_doctor_id   30000 non-null  int64
#  5   admission_date      30000 non-null  object
#  6   discharge_date      29750 non-null  object
#  7   admission_type      30000 non-null  object
#  8   diagnosis           29860 non-null  object
#  9   severity_level      30000 non-null  object
#  10  discharge_status    30000 non-null  object
#  11  readmitted_30_days  30000 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 3.0+ MB

# %%
# changing the data type of the date realted columns
admissions_clean['admission_date'] = pd.to_datetime(admissions_clean['admission_date'], errors='coerce')
admissions_clean['discharge_date'] = pd.to_datetime(admissions_clean['discharge_date'], errors='coerce')

# %%
admissions_clean['length_of_stay'] = (
    admissions_clean['discharge_date'] - admissions_clean['admission_date']
).dt.days

admissions_clean[['admission_date', 'discharge_date', 'length_of_stay']].head()
# Out:
#   admission_date discharge_date  length_of_stay
# 0     2024-03-10     2024-03-16             6.0
# 1     2023-05-19     2023-05-20             1.0
# 2     2025-06-16     2025-06-18             2.0
# 3     2025-10-15     2025-10-16             1.0
# 4     2024-05-07     2024-05-23            16.0

# %%
admissions_clean['discharge_date'].isnull().sum()
# Out:
# np.int64(250)

# %%
admissions_clean[admissions_clean['discharge_date'].isnull()]
# Out:
#        admission_id  patient_id  hospital_id  department_id  \
# 7                 8        1969            4              2
# 24               25        1965            6              3
# 267             268         605            7              5
# 343             344         589            5              5
# 409             410        1884            4             12
# ...             ...         ...          ...            ...
# 29647         29648        2834            2              4
# 29669         29670       11698            5              9
# 29916         29917         905            5              9
# 29951         29952         586            7              6
# 29971         29972       11936            8              1
#
#        primary_doctor_id admission_date discharge_date admission_type  \
# 7                     67     2025-09-30            NaT      Follow-up
# 24                   106     2024-04-09            NaT      Emergency
# 267                  247     2023-02-16            NaT      Emergency
# 343                  247     2023-06-14            NaT       Referral
# 409                   35     2025-06-03            NaT      Emergency
# ...                  ...            ...            ...            ...
# 29647                224     2025-10-25            NaT      Emergency
# 29669                  3     2023-08-30            NaT       Referral
# 29916                221     2024-09-26            NaT       Referral
# 29951                 18     2023-12-25            NaT      Emergency
# 29971                172     2025-06-28            NaT       Referral
#
#                      diagnosis severity_level discharge_status  \
# 7             Seizure Disorder           High             LAMA
# 24           Joint Replacement       Moderate             Home
# 267          COPD Exacerbation       Moderate             Home
# 343              Asthma Attack           High             Home
# 409        Respiratory Failure       Moderate      Transferred
# ...                        ...            ...              ...
# 29647   Fever Under Evaluation            Low             Home
# 29669                   Trauma       Moderate      Transferred
# 29916                   Trauma       Moderate             Home
# 29951         CKD Complication            Low             Home
# 29971  Acute Coronary Syndrome       Moderate             Home
#
#       readmitted_30_days  length_of_stay
# 7                     No             NaN
# 24                   Yes             NaN
# 267                  Yes             NaN
# 343                  Yes             NaN
# 409                  Yes             NaN
# ...                  ...             ...
# 29647                Yes             NaN
# 29669                Yes             NaN
# 29916                 No             NaN
# 29951                 No             NaN
# 29971                Yes             NaN
#
# [250 rows x 13 columns]

# %%
# Handle wrong length of stay values.
# Negative stay means discharge happened before admission, which is impossible.
admissions_clean.loc[admissions_clean['length_of_stay'] < 0, 'length_of_stay'] = np.nan

# %%
# Fill missing length of stay using median length of stay.
median_los = admissions_clean['length_of_stay'].median()
admissions_clean['length_of_stay'] = admissions_clean['length_of_stay'].fillna(median_los)

admissions_clean['length_of_stay'].describe()
# Out:
# count    30000.000000
# mean         5.915333
# std          5.432054
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         66.000000
# Name: length_of_stay, dtype: float64

# %%
admissions_clean.head()
# Out:
#    admission_id  patient_id  hospital_id  department_id  primary_doctor_id  \
# 0             1        3415            8              4                123
# 1             2        3610            8              1                209
# 2             3        7584            8              3                190
# 3             4        4459            2              3                176
# 4             5        5508            3             12                140
#
#   admission_date discharge_date admission_type                diagnosis  \
# 0     2024-03-10     2024-03-16      Emergency                   Anemia
# 1     2023-05-19     2023-05-20        Planned               Arrhythmia
# 2     2025-06-16     2025-06-18      Emergency        Joint Replacement
# 3     2025-10-15     2025-10-16       Referral        Joint Replacement
# 4     2024-05-07     2024-05-23        Planned  Multi Organ Dysfunction
#
#   severity_level discharge_status readmitted_30_days  length_of_stay
# 0       Critical             Home                Yes             6.0
# 1       Moderate             Home                 No             1.0
# 2       Moderate             Home                Yes             2.0
# 3       Moderate             Home                 No             1.0
# 4       Moderate             Home                 No            16.0

# %%
admissions_clean['readmitted_30_days'].unique()
# Out:
# array(['Yes', 'No', 'Y', 'FALSE', 'yes', 'TRUE', 'N', 'no'], dtype=object)

# %%
# Standardize readmission labels into 1 and 0.
admissions_clean['readmitted_clean'] = admissions_clean['readmitted_30_days'].astype(str).str.strip().str.lower()

admissions_clean['readmitted_flag'] = admissions_clean['readmitted_clean'].replace({
    'yes': 1,
    'y': 1,
    'true': 1,
    'no': 0,
    'n': 0,
    'false': 0,
    'nan': 0
}).astype(int)

admissions_clean['readmitted_flag'].value_counts(normalize=True) * 100
# Out:
# C:\Users\ramam\AppData\Local\Temp\ipykernel_7704\435661268.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   admissions_clean['readmitted_flag'] = admissions_clean['readmitted_clean'].replace({
# readmitted_flag
# 0    51.53
# 1    48.47
# Name: proportion, dtype: float64

# %%
admissions_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\admissions_clean.csv")

# %% [markdown]
# ### 8. Clean Treatment Cost Data

# %%
treatments_clean = treatments.copy()
print('Before duplicate removal:', treatments_clean.shape)
treatments_clean = treatments_clean.drop_duplicates()
print('After duplicate removal:', treatments_clean.shape)
# Out:
# Before duplicate removal: (90160, 7)
# After duplicate removal: (90000, 7)

# %%
treatments_clean = treatments.copy()

treatments_clean['treatment_cost'] = pd.to_numeric(
    treatments_clean['treatment_cost'],
    errors='coerce'
)

treatments_clean['cost_outlier_flag'] = 0

# %%
treatments_clean.head()
# Out:
#    treatment_id  admission_id  doctor_id treatment_type  treatment_cost  \
# 0             1         27337         62        Surgery        52636.30
# 1             2           982        242        Imaging         7478.12
# 2             3         17082        238   Chemotherapy        27451.58
# 3             4          4096          1    Lab Package         3379.43
# 4             5         26108        227       ICU Care        19993.51
#
#   treatment_date treatment_status  cost_outlier_flag
# 0     2023-01-01        Completed                  0
# 1     2023-01-01        Completed                  0
# 2     2023-01-01        Completed                  0
# 3     2023-01-01          Pending                  0
# 4     2023-01-01        Completed                  0

# %%
treatments_clean['cost_outlier_flag'].unique()
# Out:
# array([0])

# %%
treatments_clean.loc[
    (treatments_clean['treatment_cost'] < 0) | (treatments_clean['treatment_cost'] > 500000),
    'cost_outlier_flag'
] = 1

print('Number of cost outliers:', treatments_clean['cost_outlier_flag'].sum())
# Out:
# Number of cost outliers: 212

# %%
# Convert impossible treatment cost into missing value.
treatments_clean.loc[
    treatments_clean['cost_outlier_flag'] == 1,
    'treatment_cost'
] = np.nan

# %%
treatments_clean.head()
# Out:
#    treatment_id  admission_id  doctor_id treatment_type  treatment_cost  \
# 0             1         27337         62        Surgery        52636.30
# 1             2           982        242        Imaging         7478.12
# 2             3         17082        238   Chemotherapy        27451.58
# 3             4          4096          1    Lab Package         3379.43
# 4             5         26108        227       ICU Care        19993.51
#
#   treatment_date treatment_status  cost_outlier_flag
# 0     2023-01-01        Completed                  0
# 1     2023-01-01        Completed                  0
# 2     2023-01-01        Completed                  0
# 3     2023-01-01          Pending                  0
# 4     2023-01-01        Completed                  0

# %%
# Fill missing treatment cost using median cost of the same treatment type.
treatments_clean['treatment_cost_clean'] = treatments_clean.groupby('treatment_type')['treatment_cost'].transform(
    lambda values: values.fillna(values.median())
)

treatments_clean[['treatment_type', 'treatment_cost', 'treatment_cost_clean', 'cost_outlier_flag']].head()
# Out:
#   treatment_type  treatment_cost  treatment_cost_clean  cost_outlier_flag
# 0        Surgery        52636.30              52636.30                  0
# 1        Imaging         7478.12               7478.12                  0
# 2   Chemotherapy        27451.58              27451.58                  0
# 3    Lab Package         3379.43               3379.43                  0
# 4       ICU Care        19993.51              19993.51                  0

# %%
treatments_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\treatments_clean.csv")

# %% [markdown]
# ### billing clean

# %%
billing_clean = billing.copy()
print('Before duplicate removal:', billing_clean.shape)
billing_clean = billing_clean.drop_duplicates()
print('After duplicate removal:', billing_clean.shape)
# Out:
# Before duplicate removal: (30080, 10)
# After duplicate removal: (30000, 10)

# %%
billing_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30000 entries, 0 to 29999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   bill_id          30000 non-null  int64
#  1   admission_id     30000 non-null  int64
#  2   patient_id       30000 non-null  int64
#  3   payer_type       30000 non-null  object
#  4   gross_amount     29880 non-null  float64
#  5   discount_amount  30000 non-null  float64
#  6   insurance_paid   30000 non-null  float64
#  7   patient_paid     30000 non-null  float64
#  8   claim_status     30000 non-null  object
#  9   bill_date        30000 non-null  object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 2.5+ MB

# %%
billing_clean.head()
# Out:
#    bill_id  admission_id  patient_id           payer_type  gross_amount  \
# 0        1             1        3415    Premium Insurance      19940.46
# 1        2             2        3610      Basic Insurance      19034.64
# 2        3             3        7584             Self Pay      20965.03
# 3        4             4        4459  Corporate Insurance      16637.20
# 4        5             5        5508    Government Scheme      77727.52
#
#    discount_amount  insurance_paid  patient_paid claim_status   bill_date
# 0          1785.84        15939.06       2215.56         Paid  2024-03-10
# 1           558.14        13981.49       4495.01      Partial  2023-05-19
# 2          2413.86        18595.28          0.00     Rejected  2025-06-16
# 3          1938.84        13657.64       1040.72     Rejected  2025-10-15
# 4          2213.24        35959.21      39555.07         Paid  2024-05-07

# %%
billing_clean['claim_status'].unique()
# Out:
# array(['Paid', 'Partial', 'Rejected', 'Under Review', 'paid', 'PAID',
#        'Rejected ', 'under_review'], dtype=object)

# %%
billing_clean['payer_type'].unique()
# Out:
# array(['Premium Insurance', 'Basic Insurance', 'Self Pay',
#        'Corporate Insurance', 'Government Scheme'], dtype=object)

# %%
billing_clean[billing_clean['gross_amount']<0]
# Out:
# Empty DataFrame
# Columns: [bill_id, admission_id, patient_id, payer_type, gross_amount, discount_amount, insurance_paid, patient_paid, claim_status, bill_date]
# Index: []

# %%
billing_clean[billing_clean['discount_amount']<0]
# Out:
# Empty DataFrame
# Columns: [bill_id, admission_id, patient_id, payer_type, gross_amount, discount_amount, insurance_paid, patient_paid, claim_status, bill_date]
# Index: []

# %%
billing_clean[billing_clean['insurance_paid']<0]
# Out:
# Empty DataFrame
# Columns: [bill_id, admission_id, patient_id, payer_type, gross_amount, discount_amount, insurance_paid, patient_paid, claim_status, bill_date]
# Index: []

# %%
billing_clean[billing_clean['patient_paid']<0]
# Out:
# Empty DataFrame
# Columns: [bill_id, admission_id, patient_id, payer_type, gross_amount, discount_amount, insurance_paid, patient_paid, claim_status, bill_date]
# Index: []

# %%
# Clean claim_status
billing_clean['claim_status_clean'] = (
    billing_clean['claim_status']
    .astype(str)
    .str.strip()          # remove extra spaces
    .str.replace('_', ' ') # replace underscore
    .str.title()          # standardize case
)

# Check cleaned categories
billing_clean['claim_status_clean'].unique()
# Out:
# array(['Paid', 'Partial', 'Rejected', 'Under Review'], dtype=object)

# %%
billing_clean['gross_amount'] = billing_clean[
    'gross_amount'
].fillna(
    billing_clean['gross_amount'].median()
)

# %%
billing_clean['gross_amount'].isnull().sum()
# Out:
# np.int64(0)

# %%
billing_clean['bill_date_clean'] = pd.to_datetime(
    billing_clean['bill_date'],
    errors='coerce'
)

# %%
billing_clean['bill_date_clean'].dtype
# Out:
# dtype('<M8[ns]')

# %%
billing_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\billing_clean.csv")

# %% [markdown]
# ### pharmacy table cleaning

# %%
pharmacy_clean = pharmacy.copy()
print('Before duplicate removal:', pharmacy_clean.shape)
pharmacy_clean = pharmacy_clean.drop_duplicates()
print('After duplicate removal:', pharmacy_clean.shape)
# Out:
# Before duplicate removal: (70090, 8)
# After duplicate removal: (70000, 8)

# %%
pharmacy_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70000 entries, 0 to 69999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       70000 non-null  int64
#  1   admission_id   70000 non-null  int64
#  2   patient_id     70000 non-null  int64
#  3   medicine_name  70000 non-null  object
#  4   quantity       70000 non-null  int64
#  5   unit_price     70000 non-null  float64
#  6   line_amount    69850 non-null  float64
#  7   pharmacy_type  70000 non-null  object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 4.8+ MB

# %%
pharmacy_clean['line_amount_clean'] = pharmacy_clean['line_amount']
pharmacy_clean['line_amount_clean'] = pharmacy_clean[
    'line_amount_clean'
].fillna(
    pharmacy_clean['quantity'] * pharmacy_clean['unit_price']
)

# %%
pharmacy_clean[
    ['line_amount','line_amount_clean']
].head()
# Out:
#    line_amount  line_amount_clean
# 0       864.90             864.90
# 1        33.52              33.52
# 2      3207.07            3207.07
# 3       113.18             113.18
# 4      1913.64            1913.64

# %%
pharmacy_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\pharmacy_clean.csv")

# %% [markdown]
# ### labs clean data

# %%
labs_clean = labs.copy()
print('Before duplicate removal:', labs_clean.shape)
labs_clean = labs_clean.drop_duplicates()
print('After duplicate removal:', labs_clean.shape)
# Out:
# Before duplicate removal: (60000, 7)
# After duplicate removal: (60000, 7)

# %%
labs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lab_id        60000 non-null  int64
#  1   admission_id  60000 non-null  int64
#  2   patient_id    60000 non-null  int64
#  3   test_name     60000 non-null  object
#  4   test_value    59880 non-null  float64
#  5   test_date     60000 non-null  object
#  6   result_flag   60000 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 3.2+ MB

# %%
labs_clean['result_flag'].unique()
# Out:
# array(['Abnormal', 'Normal', 'Critical'], dtype=object)

# %%
labs_clean['test_value_clean'] = labs_clean['test_value']

# Fill missing values using median
labs_clean['test_value_clean'] = labs_clean[
    'test_value_clean'
].fillna(
    labs_clean['test_value_clean'].median()
)

labs_clean['test_date_clean'] = pd.to_datetime(
    labs_clean['test_date'],
    errors='coerce'
)

# %%
labs_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\labs_clean.csv")

# %% [markdown]
# ### doctors clean data

# %%
doctors_clean = doctors.copy()
print('Before duplicate removal:', doctors_clean.shape)
doctors_clean = doctors_clean.drop_duplicates()
print('After duplicate removal:', doctors_clean.shape)
# Out:
# Before duplicate removal: (260, 7)
# After duplicate removal: (260, 7)

# %%
doctors_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   doctor_id         260 non-null    int64
#  1   doctor_name       260 non-null    object
#  2   department_id     260 non-null    int64
#  3   specialization    260 non-null    object
#  4   hospital_id       260 non-null    int64
#  5   experience_years  260 non-null    int64
#  6   doctor_grade      260 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 14.3+ KB

# %%
doctors_clean.head()
# Out:
#    doctor_id      doctor_name  department_id    specialization  hospital_id  \
# 0          1   Dr. Sai Sharma              4  General Medicine            8
# 1          2     Dr. Raj Nair             12               ICU            7
# 2          3  Dr. Ishaan Khan              9         Emergency            6
# 3          4      Dr. Sai Rao              7  Gastroenterology            7
# 4          5  Dr. Priya Menon              2         Neurology            2
#
#    experience_years       doctor_grade
# 0                 9         Consultant
# 1                10           Resident
# 2                16         Consultant
# 3                 7         Consultant
# 4                12  Senior Consultant

# %%
doctors_clean['doctor_grade'].unique()
# Out:
# array(['Consultant', 'Resident', 'Senior Consultant',
#        'Visiting Consultant'], dtype=object)

# %%
doctors_clean['specialization'].unique()
# Out:
# array(['General Medicine', 'ICU', 'Emergency', 'Gastroenterology',
#        'Neurology', 'Cardiology', 'Pediatrics', 'Endocrinology',
#        'Orthopedics', 'Nephrology', 'Pulmonology', 'Oncology'],
#       dtype=object)

# %%
doctors_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\doctors_clean.csv")

# %% [markdown]
# ### followups clean data

# %%
followups_clean = followups.copy()
print('Before duplicate removal:', followups_clean.shape)
followups_clean = followups_clean.drop_duplicates()
print('After duplicate removal:', followups_clean.shape)
# Out:
# Before duplicate removal: (30000, 7)
# After duplicate removal: (30000, 7)

# %%
followups_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   followup_id         30000 non-null  int64
#  1   admission_id        30000 non-null  int64
#  2   patient_id          30000 non-null  int64
#  3   followup_due_date   30000 non-null  object
#  4   followup_completed  30000 non-null  object
#  5   followup_mode       30000 non-null  object
#  6   followup_outcome    30000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.6+ MB

# %%
followups_clean['followup_due_date_clean'] = pd.to_datetime(
    followups_clean['followup_due_date'],
    errors='coerce'
)

followups_clean['followup_due_date_clean'].dtype
# Out:
# dtype('<M8[ns]')

# %%
followups_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\followups_clean.csv")

# %%
### departments clean data

# %%
departments_clean = departments.copy()
print('Before duplicate removal:', departments_clean.shape)
departments_clean = departments_clean.drop_duplicates()
print('After duplicate removal:', departments_clean.shape)
# Out:
# Before duplicate removal: (12, 3)
# After duplicate removal: (12, 3)

# %%
departments_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   department_id    12 non-null     int64
#  1   department_name  12 non-null     object
#  2   care_complexity  12 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 420.0+ bytes

# %%
departments_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\departments_clean.csv")

# %% [markdown]
# ### hospital clean data

# %%
hospitals_clean = hospitals.copy()
print('Before duplicate removal:', hospitals_clean.shape)
hospitals_clean = hospitals_clean.drop_duplicates()
print('After duplicate removal:', hospitals_clean.shape)
# Out:
# Before duplicate removal: (8, 6)
# After duplicate removal: (8, 6)

# %%
hospitals_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hospital_id     8 non-null      int64
#  1   hospital_name   8 non-null      object
#  2   city            8 non-null      object
#  3   ownership_type  8 non-null      object
#  4   bed_capacity    8 non-null      int64
#  5   launch_year     8 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 516.0+ bytes

# %%
hospitals_clean.to_csv(r"C:\Users\ramam\Downloads\Health_Operations\hospitals_clean.csv")

# %% [markdown]
# ### 9. Aggregate Transaction Data to Admission Level

# %%
treatment_summary = treatments_clean.groupby('admission_id').agg(
    total_treatment_cost = ('treatment_cost_clean', 'sum'),
    treatment_count = ('treatment_id', 'count'),
    treatment_outlier_count = ('cost_outlier_flag', 'sum')
).reset_index()

treatment_summary.head()
# Out:
#    admission_id  total_treatment_cost  treatment_count  \
# 0             1              13633.72                3
# 1             2              16345.82                2
# 2             3               7095.49                2
# 3             4               7229.08                2
# 4             5              75709.09                3
#
#    treatment_outlier_count
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
pharmacy_clean = pharmacy.copy()
pharmacy_clean['line_amount'] = pd.to_numeric(pharmacy_clean['line_amount'], errors='coerce')
pharmacy_clean['line_amount_clean'] = pharmacy_clean['line_amount'].fillna(pharmacy_clean['line_amount'].median())

pharmacy_summary = pharmacy_clean.groupby('admission_id').agg(
    total_pharmacy_cost = ('line_amount_clean', 'sum'),
    medicine_count = ('order_id', 'count')
).reset_index()

pharmacy_summary.head()
# Out:
#    admission_id  total_pharmacy_cost  medicine_count
# 0             1              1437.36               2
# 1             2              1173.55               1
# 2             3              3801.23               4
# 3             4              7116.67               5
# 4             6              3218.53               2

# %%
labs_clean = labs.copy()

lab_summary = labs_clean.groupby('admission_id').agg(
    lab_test_count = ('lab_id', 'count'),
    abnormal_lab_count = ('result_flag', lambda x: x.isin(['Abnormal', 'Critical']).sum()),
    critical_lab_count = ('result_flag', lambda x: (x == 'Critical').sum())
).reset_index()

lab_summary.head()
# Out:
#    admission_id  lab_test_count  abnormal_lab_count  critical_lab_count
# 0             1               1                   1                   0
# 1             2               1                   0                   0
# 2             3               2                   1                   0
# 3             4               1                   0                   0
# 4             5               1                   0                   0

# %% [markdown]
# ### 10. Create Final Analytics Table

# %%
analytics = admissions_clean.merge(
    patients_clean[['patient_id', 'age_clean', 'gender_clean', 'city', 'chronic_condition_clean', 'chronic_flag']],
    on='patient_id',
    how='left'
)

analytics = analytics.merge(departments, on='department_id', how='left')
analytics = analytics.merge(hospitals, on='hospital_id', how='left')
analytics = analytics.merge(doctors, left_on='primary_doctor_id', right_on='doctor_id', how='left')
analytics = analytics.merge(treatment_summary, on='admission_id', how='left')
analytics = analytics.merge(pharmacy_summary, on='admission_id', how='left')
analytics = analytics.merge(lab_summary, on='admission_id', how='left')

analytics.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 2
#       1 analytics = admissions_clean.merge(
# ----> 2     patients_clean[['patient_id', 'age_clean', 'gender_clean', 'city', 'chronic_condition_clean', 'chronic_flag']],
#       3     on='patient_id',
#       4     how='left'
#       5 )
#       7 analytics = analytics.merge(departments, on='department_id', how='left')
#       8 analytics = analytics.merge(hospitals, on='hospital_id', how='left')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['age_clean', 'gender_clean', 'chronic_condition_clean', 'chronic_flag'] not in index"

# %%
# Fill missing totals with 0.
# Reason: if there is no pharmacy record, pharmacy cost should be treated as 0 for that admission.
amount_columns = [
    'total_treatment_cost',
    'total_pharmacy_cost',
    'treatment_count',
    'medicine_count',
    'lab_test_count',
    'abnormal_lab_count',
    'critical_lab_count'
]

for column in amount_columns:
    analytics[column] = analytics[column].fillna(0)

analytics['total_clinical_cost'] = analytics['total_treatment_cost'] + analytics['total_pharmacy_cost']
analytics['cost_per_day'] = analytics['total_clinical_cost'] / analytics['length_of_stay'].replace(0, np.nan)
analytics['cost_per_day'] = analytics['cost_per_day'].fillna(0)

analytics[['total_treatment_cost', 'total_pharmacy_cost', 'total_clinical_cost', 'cost_per_day']].head()

# %% [markdown]
# ### 11. Feature Engineering: Patient History and Risk Score

# %%
analytics = analytics.sort_values(['patient_id', 'admission_date'])

analytics['previous_admission_date'] = analytics.groupby('patient_id')['admission_date'].shift(1)
analytics['previous_discharge_date'] = analytics.groupby('patient_id')['discharge_date'].shift(1)

analytics['readmission_gap_days'] = (
    analytics['admission_date'] - analytics['previous_discharge_date']
).dt.days

analytics['previous_admissions'] = analytics.groupby('patient_id').cumcount()

analytics[['patient_id', 'admission_date', 'previous_discharge_date', 'readmission_gap_days', 'previous_admissions']].head(10)

# %%
# his is not a machine learning model.
# It is a business rule score that management can understand.

analytics['age_score'] = np.where(analytics['age_clean'] >= 60, 2, 1)
analytics['chronic_score'] = np.where(analytics['chronic_flag'] == 1, 2, 0)
analytics['visit_score'] = np.where(analytics['previous_admissions'] >= 2, 2, 0)
analytics['lab_score'] = np.where(analytics['critical_lab_count'] >= 1, 2, 0)
analytics['los_score'] = np.where(analytics['length_of_stay'] >= 7, 1, 0)

analytics['patient_risk_score'] = (
    analytics['age_score'] +
    analytics['chronic_score'] +
    analytics['visit_score'] +
    analytics['lab_score'] +
    analytics['los_score']
)

analytics['risk_segment'] = pd.cut(
    analytics['patient_risk_score'],
    bins=[-1, 2, 5, 10],
    labels=['Low Risk', 'Medium Risk', 'High Risk']
)

analytics[['patient_risk_score', 'risk_segment' ]].head()

# %% [markdown]
# ### 12. Univariate Analysis

# %%
plt.figure(figsize=(8, 4))
plt.hist(analytics['age_clean'], bins=20)
plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Number of Admissions')
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.hist(analytics['risk_segment'], bins=20)
plt.title(' parients wise risk analysis')
plt.xlabel('risk_age')
plt.ylabel('Number of Admissions')
plt.show()

# %%
plt.figure(figsize=(22, 6))
plt.hist(analytics['department_name'], bins=20)
plt.title('department wise Distribution of Patients')
plt.xlabel('department')
plt.ylabel('Number of Admissions')
plt.show()

# %%
departments_clean.head()

# %% [markdown]
# ### 13. Bivariate Analysis

# %%
readmission_by_risk = analytics.groupby('risk_segment')['readmitted_flag'].mean().reset_index()
readmission_by_risk['readmission_rate_percentage'] = readmission_by_risk['readmitted_flag'] * 100
readmission_by_risk

# %%
plt.figure(figsize=(8, 4))
plt.bar(readmission_by_risk['risk_segment'].astype(str), readmission_by_risk['readmission_rate_percentage'])
plt.title('Readmission Rate by Patient Risk Segment')
plt.xlabel('Risk Segment')
plt.ylabel('Readmission Rate (%)')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.bar(analytics['department_name'], analytics['total_clinical_cost'])
plt.xticks(rotation=45, ha='right')
plt.title('Average Clinical Cost by Department')
plt.xlabel('Department')
plt.ylabel('Average Cost')
plt.show()

# %%
plt.figure(figsize=(22, 6))

total_cost = analytics.groupby('department_name')['total_clinical_cost'].sum()

plt.bar(total_cost.index.astype(str), total_cost.values)

plt.title('Department Wise Total Cost')
plt.xlabel('Department Name')
plt.ylabel('Total Cost')

plt.show()

# %% [markdown]
# ### 14. Multivariate Analysis

# %%
multi_analysis = analytics.groupby(
    ['department_name', 'chronic_condition_clean']
).agg(
    admissions = ('admission_id', 'count'),
    readmission_rate = ('readmitted_flag', 'mean'),
    average_cost = ('total_clinical_cost', 'mean'),
    average_length_of_stay = ('length_of_stay', 'mean')
).reset_index()

multi_analysis['readmission_rate'] = multi_analysis['readmission_rate'] * 100
multi_analysis.sort_values('readmission_rate', ascending=False).head(15)

# %% [markdown]
# ### 15. Doctor Performance Audit Table

# %%
doctor_audit = analytics.groupby(['doctor_id', 'doctor_name']).agg(
    admissions_handled = ('admission_id', 'count'),
    average_risk_score = ('patient_risk_score', 'mean'),
    readmission_rate = ('readmitted_flag', 'mean'),
    average_cost = ('total_clinical_cost', 'mean'),
    average_length_of_stay = ('length_of_stay', 'mean')
).reset_index()

doctor_audit['readmission_rate'] = doctor_audit['readmission_rate'] * 100

doctor_audit = doctor_audit.sort_values('readmission_rate', ascending=False)
doctor_audit.head(10)

# %% [markdown]
# ### 16. Final Executive Summary

# %%
overall_readmission_rate = analytics['readmitted_flag'].mean() * 100
average_cost = analytics['total_clinical_cost'].mean()
average_los = analytics['length_of_stay'].mean()
high_risk_readmission_rate = analytics.loc[analytics['risk_segment'] == 'High Risk', 'readmitted_flag'].mean() * 100

print('EXECUTIVE SUMMARY')
print('-----------------')
print(f'Overall readmission rate: {overall_readmission_rate:.2f}%')
print(f'Average clinical cost per admission: {average_cost:,.2f}')
print(f'Average length of stay: {average_los:.2f} days')
print(f'High-risk patient readmission rate: {high_risk_readmission_rate:.2f}%')

# %% [markdown]
# ### 17. Business Recommendations

# %% [markdown]
# ### 18. Export Clean Final Dataset

# %%
output_file = 'hospital_project.csv'
analytics.to_csv(output_file, index=False)
print('Saved file:', output_file)
